# %% [markdown]
# """ Image Extraction """

# %%
#pip install selenium

# %%
import pandas as pd

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
def scroll_down_slowly():
    driver.execute_script("window.scrollBy(0, 500)")
    time.sleep(1)

def extract_data_from_page():
    brand_names = driver.find_elements(By.CSS_SELECTOR, 'div.product-productMetaInfo > h3')
    product_descriptions = driver.find_elements(By.XPATH, "//*[@class='product-product']")
    discount_prices = driver.find_elements(By.XPATH, '//*[@class="product-discountedPrice"]')
    original_prices = driver.find_elements(By.XPATH, '//span[@class="product-strike"]')
    discounts = driver.find_elements(By.XPATH, '//span[@class="product-discountPercentage"]')
    img_data = driver.find_elements(By.CSS_SELECTOR, 'img.img-responsive')
    image_elements = driver.find_elements(By.XPATH, '//source')

    data_list = []

    for i in range(len(brand_names)):
        data = {
            'Brand_Name': brand_names[i].text.strip() if i < len(brand_names) else '',
            'Product_Description' :product_descriptions[i].text.strip() if i < len(product_descriptions) else '',
            'Product_Detail_Description':  img_data[i].get_attribute('title') if i < len(img_data) else '' ,
            'Discounted_Price': discount_prices[i].text.strip() if i < len(discount_prices) else '',
            'Original_Price': original_prices[i].text.strip() if i < len(original_prices) else '',
            'Discount_Percent': discounts[i].text.strip() if i < len(discounts) else '',
            'Links_of_the_Product_Images': img_data[i].get_attribute('src') if i < len(img_data) else '',
            'Links_of_the_Product_Zoomed_Images': image_elements[i].get_attribute('srcset') if i < len(image_elements) else ''
            
        }
        data_list.append(data)

    return data_list

columns = ['Brand_Name', 'Product_Description','Product_Detail_Description', 'Discounted_Price', 'Original_Price', 'Discount_Percent', 'Links_of_the_Product_Images', 'Links_of_the_Product_Zoomed_Images']
data_list = []

driver = webdriver.Chrome()

for page_number in range(1, 55):
    page_url = f"https://www.myntra.com/men-tshirts?p={page_number}"
    driver.get(page_url)
    driver.maximize_window()


    for _ in range(10):
        scroll_down_slowly()

    page_data = extract_data_from_page()

    data_list.extend(page_data)


df = pd.DataFrame(data_list)


print("Final DataFrame:")
df.head()
# Out:
# Final DataFrame:
#              Brand_Name        Product_Description  \
# 0                   H&M  Men Oversized Fit Tshirts
# 1  UnderJeans by Spykar  Men Cotton Lounge Tshirts
# 2  UnderJeans by Spykar  Men Cotton Lounge Tshirts
# 3                  Nike     Jordan Dri-Fit Tshirts
# 4                   max         Men Lounge Tshirts
#
#                        Product_Detail_Description Discounted_Price  \
# 0                   H&M Men Oversized Fit Tshirts          Rs. 399
# 1  UnderJeans by Spykar Men Cotton Lounge Tshirts          Rs. 399
# 2  UnderJeans by Spykar Men Cotton Lounge Tshirts          Rs. 539
# 3     Nike Jordan Dri-Fit Men Performance Tshirts          Rs. 539
# 4                     max Men Blue Lounge Tshirts          Rs. 999
#
#   Original_Price Discount_Percent  \
# 0        Rs. 799    (Rs. 400 OFF)
# 1        Rs. 799    (Rs. 400 OFF)
# 2        Rs. 599        (10% OFF)
# 3        Rs. 599        (10% OFF)
# 4       Rs. 1999        (50% OFF)
#
#                          Links_of_the_Product_Images  \
# 0  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 1  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 3  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 4  https://assets.myntassets.com/dpr_2,q_60,w_210...
#
#                   Links_of_the_Product_Zoomed_Images
# 0  \n    https://assets.myntassets.com/f_webp,dpr...
# 1  \n    https://assets.myntassets.com/f_webp,dpr...
# 2  \n    https://assets.myntassets.com/f_webp,dpr...
# 3  \n    https://assets.myntassets.com/f_webp,dpr...
# 4  \n    https://assets.myntassets.com/f_webp,dpr...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Brand_Name                          2350 non-null   object
#  1   Product_Description                 2350 non-null   object
#  2   Product_Detail_Description          2350 non-null   object
#  3   Discounted_Price                    2350 non-null   object
#  4   Original_Price                      2350 non-null   object
#  5   Discount_Percent                    2350 non-null   object
#  6   Links_of_the_Product_Images         2350 non-null   object
#  7   Links_of_the_Product_Zoomed_Images  2350 non-null   object
# dtypes: object(8)
# memory usage: 147.0+ KB

# %% [markdown]
# """ Visualization """

# %%
df.head(2)
# Out:
#              Brand_Name        Product_Description  \
# 0                   H&M  Men Oversized Fit Tshirts
# 1  UnderJeans by Spykar  Men Cotton Lounge Tshirts
#
#                        Product_Detail_Description Discounted_Price  \
# 0                   H&M Men Oversized Fit Tshirts          Rs. 399
# 1  UnderJeans by Spykar Men Cotton Lounge Tshirts          Rs. 399
#
#   Original_Price Discount_Percent  \
# 0        Rs. 799    (Rs. 400 OFF)
# 1        Rs. 799    (Rs. 400 OFF)
#
#                          Links_of_the_Product_Images  \
# 0  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 1  https://assets.myntassets.com/dpr_2,q_60,w_210...
#
#                   Links_of_the_Product_Zoomed_Images
# 0  \n    https://assets.myntassets.com/f_webp,dpr...
# 1  \n    https://assets.myntassets.com/f_webp,dpr...

# %%
# pip install plotly

# %%
import plotly.express as px
discount_counts = df["Discount_Percent"].value_counts()
filtered_df = df[df["Discount_Percent"].isin(discount_counts.index)]
fig = px.bar(filtered_df, x='Discount_Percent',title='Discounted Percent Counts')
fig.show()

# %%
discount_counts = df["Brand_Name"].value_counts()
filtered_df = df[df["Brand_Name"].isin(discount_counts.index)]
fig = px.bar(filtered_df, x='Brand_Name', title='Brand Name Counts')
fig.show()

# %% [markdown]
# """ Data Organization "and Store""

# %%
df.head(25)
# Out:
#                Brand_Name             Product_Description  \
# 0                     H&M       Men Oversized Fit Tshirts
# 1    UnderJeans by Spykar       Men Cotton Lounge Tshirts
# 2    UnderJeans by Spykar       Men Cotton Lounge Tshirts
# 3                    Nike          Jordan Dri-Fit Tshirts
# 4                     max              Men Lounge Tshirts
# 5                     max              Men Lounge Tshirts
# 6                 Raymond             Men Printed Tshirts
# 7   HRX by Hrithik Roshan           Men Pack Of 2 Tshirts
# 8                     max              Men Lounge Tshirts
# 9                     max              Men Lounge Tshirts
# 10                    H&M       Loose Fit Printed T-shirt
# 11  HRX by Hrithik Roshan   Racketsport Rapid-Dry Tshirts
# 12  HRX by Hrithik Roshan      Training Rapid-Dry Tshirts
# 13  HRX by Hrithik Roshan      Training Rapid-Dry Tshirts
# 14               Roadster        Cotton Oversized Tshirts
# 15  HRX by Hrithik Roshan   Racketsport Rapid-Dry Tshirts
# 16  HRX by Hrithik Roshan      Lifestyle Bio-Wash Tshirts
# 17             Van Heusen  Men Pure Cotton Lounge Tshirts
# 18                    max           Cotton Lounge Tshirts
#
#                           Links_of_the_Product_Images  \
# 0   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 1   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 3   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 4   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 5   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 6   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 7   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 8   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 9   https://assets.myntassets.com/dpr_2,q_60,w_210...
# 10  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 11  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 12  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 13  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 14  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 15  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 16  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 17  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 18  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 19  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 20  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 21  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 22  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 23  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 24  https://assets.myntassets.com/dpr_2,q_60,w_210...
#
#                    Links_of_the_Product_Zoomed_Images
# 0   \n    https://assets.myntassets.com/f_webp,dpr...
# 1   \n    https://assets.myntassets.com/f_webp,dpr...
# 2   \n    https://assets.myntassets.com/f_webp,dpr...
# 3   \n    https://assets.myntassets.com/f_webp,dpr...
# 4   \n    https://assets.myntassets.com/f_webp,dpr...
# 5   \n    https://assets.myntassets.com/f_webp,dpr...
# 6   \n    https://assets.myntassets.com/f_webp,dpr...
# 7   \n    https://assets.myntassets.com/f_webp,dpr...
# 8   \n    https://assets.myntassets.com/f_webp,dpr...
# 9   \n    https://assets.myntassets.com/f_webp,dpr...
# 10  \n    https://assets.myntassets.com/f_webp,dpr...
# 11  \n    https://assets.myntassets.com/f_webp,dpr...
# 12  \n    https://assets.myntassets.com/f_webp,dpr...
# 13  \n    https://assets.myntassets.com/f_webp,dpr...
# 14  \n    https://assets.myntassets.com/f_webp,dpr...
# 15  \n    https://assets.myntassets.com/f_webp,dpr...
# 16  \n    https://assets.myntassets.com/f_webp,dpr...
# 17  \n    https://assets.myntassets.com/f_webp,dpr...
# 18  \n    https://assets.myntassets.com/f_webp,dpr...
# 19  \n    https://assets.myntassets.com/f_webp,dpr...
# 20  \n    https://assets.myntassets.com/f_webp,dpr...
# 21  \n    https://assets.myntassets.com/f_webp,dpr...
# 22  \n    https://assets.myntassets.com/f_webp,dpr...
# 23  \n    https://assets.myntassets.com/f_webp,dpr...
# 24  \n    https://assets.myntassets.com/f_webp,dpr...

# %%
df.to_csv("myntra.csv")

# %%
import lancedb
from lancedb.embeddings import EmbeddingFunctionRegistry
import pandas as pd
from lancedb.pydantic import LanceModel, Vector
from lancedb.embeddings import get_registry

# %%
registry = EmbeddingFunctionRegistry.get_instance()
clip = registry.get("open-clip").create()

# %%
clip
# Out:
# OpenClipEmbeddings(max_retries=7, name='ViT-B-32', pretrained='laion2b_s34b_b79k', device='cpu', batch_size=64, normalize=True)

# %%
registry = EmbeddingFunctionRegistry.get_instance()
clip = registry.get("open-clip").create(query_task_type="retrieval_query")
class MyntraImgModel(LanceModel):
    Brand_Name: str 
    Product_Description: str 
    Product_Detail_Description : str = clip.SourceField() 
    Discounted_Price: str
    Original_Price:str
    Discount_Percent : str
    Links_of_the_Product_Images: str = clip.SourceField()
# 2348             bigbanana              Plus Size Cotton T-shirt
# 2349              Bewakoof                Printed Cotton T-shirt
#
#                              Product_Detail_Description Discounted_Price  \
# 0                         H&M Men Oversized Fit Tshirts          Rs. 399
# 1        UnderJeans by Spykar Men Cotton Lounge Tshirts          Rs. 399
# 2        UnderJeans by Spykar Men Cotton Lounge Tshirts          Rs. 539
# 3           Nike Jordan Dri-Fit Men Performance Tshirts          Rs. 539
# 4                           max Men Blue Lounge Tshirts          Rs. 999
# ...                                                 ...              ...
# 2345       HERE&NOW Graphic Printed Pure Cotton T-shirt          Rs. 791
# 2346           max Men Henley Neck Long Sleeves T-shirt          Rs. 799
# 2347  WROGN Men Blue  White Slim Fit Striped Round N...
# 2348  bigbanana Plus Size Polo Collar Bio Finish Cot...
# 2349  Bewakoof White Peanuts Typography Printed Polo...
#
#      Original_Price Discount_Percent  \
# 0           Rs. 799    (Rs. 400 OFF)
# 1           Rs. 799    (Rs. 400 OFF)
# 2           Rs. 599        (10% OFF)
# 3           Rs. 599        (10% OFF)
# 4          Rs. 1999        (50% OFF)
# ...             ...              ...
# 2345       Rs. 2199        (64% OFF)
# 2346       Rs. 1399    (Rs. 600 OFF)
# 2347
# 2348
# 2349
#
#                             Links_of_the_Product_Images  \
# 0     https://assets.myntassets.com/dpr_2,q_60,w_210...
# 1     https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2     https://assets.myntassets.com/dpr_2,q_60,w_210...
# 3     https://assets.myntassets.com/dpr_2,q_60,w_210...
# 4     https://assets.myntassets.com/dpr_2,q_60,w_210...
# ...                                                 ...
# 2345  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2346  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2347  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2348  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2349  https://assets.myntassets.com/dpr_2,q_60,w_210...
#
#                      Links_of_the_Product_Zoomed_Images  \
# 0     \n    https://assets.myntassets.com/f_webp,dpr...
# 1     \n    https://assets.myntassets.com/f_webp,dpr...
# 2     \n    https://assets.myntassets.com/f_webp,dpr...
# 3     \n    https://assets.myntassets.com/f_webp,dpr...
# 4     \n    https://assets.myntassets.com/f_webp,dpr...
# ...                                                 ...
# 2345  \n    https://assets.myntassets.com/f_webp,dpr...
# 2346  \n    https://assets.myntassets.com/f_webp,dpr...
# 2347  \n    https://assets.myntassets.com/f_webp,dpr...
# 2348  \n    https://assets.myntassets.com/f_webp,dpr...
# 2349  \n    https://assets.myntassets.com/f_webp,dpr...
#
#                                                  vector
# 0     [-0.028400116, 0.036771044, -0.0034671894, -0....
# 1     [0.017915007, 0.007537149, -0.09663298, -0.025...
# 2     [-0.008967035, -0.045339134, -0.04415968, -0.0...
# 3     [0.0038396136, -0.1641526, -0.04768233, -0.085...
# 4     [-0.020177975, -0.019878946, -0.034531135, -0....
# ...                                                 ...
# 2345  [-0.03277545, 0.065940775, -0.09226745, 0.0100...
# 2346  [0.031508572, 0.03103918, -0.041060038, 0.0138...
# 2347  [-0.02914806, 0.1571751, -0.13937947, -0.02426...
# 2348  [-0.029935656, -0.025772281, -0.05752768, -0.0...
# 2349  [0.010416982, -0.18840681, -0.10222505, -0.059...
#
# [2350 rows x 9 columns]

# %%
rs_img = tbl.search("Roadster Men Colourblocked Polo Collar T-shirt").metric("cosine").limit(5).to_pandas()
rs_img
# Out:
#   Brand_Name                Product_Description  \
# 0   HERE&NOW           Pure Cotton Polo T-shirt
# 1   Roadster                Polo Collar T-shirt
# 2   HERE&NOW         Pure Cotton Casual T-shirt
# 3     V-Mart             Striped Cotton T-shirt
# 4     VEIRDO  Colourblocked Polo Collar T-shirt
#
#                           Product_Detail_Description Discounted_Price  \
# 0  HERE&NOW Colourblocked Polo Collar Pure Cotton...          Rs. 447
# 1             Roadster Men Black Polo Collar T-shirt          Rs. 395
# 2  HERE&NOW Pure Cotton Colourblocked Polo Collar...          Rs. 779
# 3          V-Mart Striped Cotton Polo Collar T-shirt          Rs. 350
# 4  VEIRDO Men Maroon Colourblocked Polo Collar T-...          Rs. 539
#
#   Original_Price Discount_Percent  \
# 0       Rs. 1599        (72% OFF)
# 1       Rs. 1580        (75% OFF)
# 2       Rs. 1299        (40% OFF)
# 3       Rs. 1399   (Rs. 1049 OFF)
# 4       Rs. 1199        (55% OFF)
#
#                          Links_of_the_Product_Images  \
# 0  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 1  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 3  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 4  https://assets.myntassets.com/dpr_2,q_60,w_210...
#
#                   Links_of_the_Product_Zoomed_Images  \
# 0  \n    https://assets.myntassets.com/f_webp,dpr...
# 1  \n    https://assets.myntassets.com/f_webp,dpr...
# 2  \n    https://assets.myntassets.com/f_webp,dpr...
# 3  \n    https://assets.myntassets.com/f_webp,dpr...
# 4  \n    https://assets.myntassets.com/f_webp,dpr...
#
#                                               vector  _distance
# 0  [0.009707565, -0.084677525, -0.0870261, -0.053...   0.648957
# 1  [0.037191845, 0.028895363, -0.06364451, -0.041...   0.651013
# 2  [0.013003089, 0.10439553, -0.07990084, -0.0495...   0.651609
# 3  [-0.017243363, -0.0054176254, -0.05614691, -0....   0.652789
# 4  [0.011808185, -0.025338707, -0.06779515, -0.07...   0.654133

# %%
def find_best_passage(query):
    rs_img = tbl.search(query).metric("cosine").limit(5).to_pandas()
    img_path =  rs_img['Links_of_the_Product_Images'].tolist()
    return (img_path)

# %%
img = find_best_passage("Roadster Men Colourblocked Polo Collar T-shirt")

# %%
from IPython.display import display, Image
for image_url in img:
    display(Image(url=image_url))
# Out:
# <img src="https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/24430562/2023/11/20/f9ff68a7-6fee-4db9-82b9-9dcb98076f181700477548551-HERENOW-Men-Tshirts-2621700477548172-1.jpg"/>
# <img src="https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/2337637/2018/2/8/11518089132423-Roadster-Men-Black-Solid-Polo-Collar-T-shirt-9911518089132200-1.jpg"/>
# <img src="https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/24430616/2023/11/20/d93e1a5e-d53c-4b37-aefa-f3699faa37c71700473103617-HERENOW-Men-Tshirts-4721700473103272-1.jpg"/>
# <img src="https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/26702092/2023/12/28/4d1c1092-08a8-4755-b5eb-cbe7456d3c5b1703754268385V-MartMenBrownBrownStripedPoloCollarT-shirt1.jpg"/>
# <img src="https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/11925912/2020/7/15/5437851a-449c-4d76-a52b-fcc12fa7df571594809640266-VEIRDO-Men-Tshirts-4671594809638036-1.jpg"/>
